# %%
import os
folder_path = "C:/Users/EKTA/Downloads/Github/Real-World Data Cleaning"
os.chdir(folder_path)

# %%
import pandas as pd

# %%
data = pd.read_csv("Airbnb_Open_Data.csv")
data.head()
# Out:
# C:\Users\EKTA\AppData\Local\Temp\ipykernel_32564\1113942449.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("Airbnb_Open_Data.csv")
#         id                                              NAME      host id  \
# 0  1001254                Clean & quiet apt home by the park  80014485718
# 1  1002102                             Skylit Midtown Castle  52335172823
# 2  1002403               THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3  1002755                                               NaN  85098326012
# 4  1003689  Entire Apt: Spacious Studio/Loft by central park  92037596077
#
#   host_identity_verified host name neighbourhood group neighbourhood  \
# 0            unconfirmed  Madaline            Brooklyn    Kensington
# 1               verified     Jenna           Manhattan       Midtown
# 2                    NaN     Elise           Manhattan        Harlem
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102599 entries, 0 to 102598
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   id                              102599 non-null  int64
#  1   NAME                            102349 non-null  object
#  2   host id                         102599 non-null  int64
#  3   host_identity_verified          102310 non-null  object
#  4   host name                       102193 non-null  object
#  5   neighbourhood group             102570 non-null  object
#  6   neighbourhood                   102583 non-null  object
#  7   lat                             102591 non-null  float64
#  8   long                            102591 non-null  float64
#  9   country                         102067 non-null  object
#  10  country code                    102468 non-null  object
#  11  instant_bookable                102494 non-null  object
# ...

# %%
data.shape #original shape
# Out:
# (102599, 26)

# %% [markdown]
# ##### 1st method: Deleting redundant columns

# %%
data.columns
# Out:
# Index(['id', 'NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review', 'reviews per month',
#        'review rate number', 'calculated host listings count',
#        'availability 365', 'house_rules', 'license'],
#       dtype='object')

# %%
columns_to_keep = ['NAME', 'host id', 'host_identity_verified', 'host name',
       'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
       'country code', 'instant_bookable', 'cancellation_policy', 'room type',
       'Construction year', 'price', 'service fee', 'minimum nights',
       'number of reviews', 'last review']
columns_to_drop = ['id','reviews per month',
       'review rate number', 'calculated host listings count',
       'availability 365', 'house_rules', 'license']

# %%
len(columns_to_keep)
# Out:
# 19

# %%
len(columns_to_drop)
# Out:
# 7

# %% [markdown]
# ##### Filtering

# %%
df = data[columns_to_keep]
df
# Out:
#                                                     NAME      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
df.shape  #shape updated in data because we kepts only 'columns_to_keep' inside the df variable
# Out:
# (102599, 19)

# %% [markdown]
# ##### 2nd method : Dropping the columns

# %%
data.drop(columns=columns_to_drop,inplace = True) #made change directly in original data .. even data=data.drop(columns=columns_to_drop,inplace = True) would have worked

# %%
data.shape
# Out:
# (102599, 19)

# %% [markdown]
# ##### Renaming the columns

# %%
data.columns
# Out:
# Index(['NAME', 'host id', 'host_identity_verified', 'host name',
#        'neighbourhood group', 'neighbourhood', 'lat', 'long', 'country',
#        'country code', 'instant_bookable', 'cancellation_policy', 'room type',
#        'Construction year', 'price', 'service fee', 'minimum nights',
#        'number of reviews', 'last review'],
#       dtype='object')

# %%
data.rename(columns = {'NAME': 'Name'}, inplace = True) #but there are too many columns to be renamed.

# %%
new_column_names = []
for i in data.columns:
    new_column_names.append(i.lower())

new_column_names
# Out:
# ['name',
#  'host id',
#  'host_identity_verified',
#  'host name',
#  'neighbourhood group',
#  'neighbourhood',
#  'lat',
#  'long',
#  'country',
#  'country code',
#  'instant_bookable',
#  'cancellation_policy',
#  'room type',
#  'construction year',
#  'price',
#  'service fee',
#  'minimum nights',
#  'number of reviews',
#  'last review']

# %%
new_dataframe_to_modify = data.copy()
new_dataframe_to_modify
# Out:
#                                                     Name      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %%
new_dataframe_to_modify.columns = new_column_names   #we created sepearte dataset for renamed column, instead of modifying original dataset.  we can use this or keep using original dataset stored in variable 'data'
new_dataframe_to_modify
# Out:
#                                                     name      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 2                    THE VILLAGE OF HARLEM....NEW YORK !  78829239556
# 3                                                    NaN  85098326012
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# ...                                                  ...          ...
# 102594                        Spare room in Williamsburg  12312296767
# 102595                     Best Location near Columbia U  77864383453
# 102596                    Comfy, bright room in Brooklyn  69050334417
# 102597                  Big Studio-One Stop from Midtown  11160591270
# 102598                              585 sf Luxury Studio  68170633372
#
#        host_identity_verified    host name neighbourhood group  \
# ...

# %% [markdown]
# ##### Dropping duplicates

# %%
data.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 102594     True
# 102595     True
# 102596     True
# 102597     True
# 102598     True
# Length: 102599, dtype: bool

# %%
data.duplicated().sum()
# Out:
# np.int64(541)

# %%
data.drop_duplicates(inplace = True)
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ##### Removing NaN values from the dtataset

# %%
data.isna().sum()
# Out:
# Name                        250
# host id                       0
# host_identity_verified      289
# host name                   404
# neighbourhood group          29
# neighbourhood                16
# lat                           8
# long                          8
# country                     532
# country code                131
# instant_bookable            105
# cancellation_policy          76
# room type                     0
# Construction year           214
# price                       247
# service fee                 273
# minimum nights              400
# number of reviews           183
# last review               15832
# dtype: int64

# %%
data.drop(columns = ["last review"], inplace  = True)  #we dropped this column which is having significantly high NA values

# %%
data.isna().sum()
# Out:
# Name                      250
# host id                     0
# host_identity_verified    289
# host name                 404
# neighbourhood group        29
# neighbourhood              16
# lat                         8
# long                        8
# country                   532
# country code              131
# instant_bookable          105
# cancellation_policy        76
# room type                   0
# Construction year         214
# price                     247
# service fee               273
# minimum nights            400
# number of reviews         183
# dtype: int64

# %%
#removing rest of the NA values
data.dropna(inplace = True)

# %%
data.isna().sum()
# Out:
# Name                      0
# host id                   0
# host_identity_verified    0
# host name                 0
# neighbourhood group       0
# neighbourhood             0
# lat                       0
# long                      0
# country                   0
# country code              0
# instant_bookable          0
# cancellation_policy       0
# room type                 0
# Construction year         0
# price                     0
# service fee               0
# minimum nights            0
# number of reviews         0
# dtype: int64

# %% [markdown]
# ##### Cleaning individual column

# %%
data['host_identity_verified'].str.upper()
# Out:
# 0         UNCONFIRMED
# 1            VERIFIED
# 4            VERIFIED
# 5            VERIFIED
# 7         UNCONFIRMED
#              ...
# 102029    UNCONFIRMED
# 102030       VERIFIED
# 102031       VERIFIED
# 102032    UNCONFIRMED
# 102040       VERIFIED
# Name: host_identity_verified, Length: 99342, dtype: object

# %%
data['host_identity_verified'] = data['host_identity_verified'].str.upper() #replaced the old column with modified.

# %%
data
# Out:
#                                                     Name      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5              Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                        BlissArtsSpace!  90821839709
# ...                                                  ...          ...
# 102029            Cozy room in a 2B with backyard access   5155155913
# 102030                      An East Williamsburg Delight  71564706996
# 102031                      Cozy bedroom in williamsburg  83101851929
# 102032                            Spacious Room w/ 2 Bed  69037598918
# 102040                     Room in Queens, NY, near LGA.  56457739998
#
#        host_identity_verified  host name neighbourhood group  \
# 0                 UNCONFIRMED   Madaline            Brooklyn
# ...

# %%
data['instant_bookable'].apply(lambda x: 1 if x == True else 0)
# Out:
# 0         0
# 1         0
# 4         0
# 5         1
# 7         0
#          ..
# 102029    0
# 102030    1
# 102031    1
# 102032    0
# 102040    1
# Name: instant_bookable, Length: 99342, dtype: int64

# %%
data['instant_bookable'] = data['instant_bookable'].apply(lambda x: 1 if x == True else 0)

# %%
data
# Out:
#                                                     Name      host id  \
# 0                     Clean & quiet apt home by the park  80014485718
# 1                                  Skylit Midtown Castle  52335172823
# 4       Entire Apt: Spacious Studio/Loft by central park  92037596077
# 5              Large Cozy 1 BR Apartment In Midtown East  45498551794
# 7                                        BlissArtsSpace!  90821839709
# ...                                                  ...          ...
# 102029            Cozy room in a 2B with backyard access   5155155913
# 102030                      An East Williamsburg Delight  71564706996
# 102031                      Cozy bedroom in williamsburg  83101851929
# 102032                            Spacious Room w/ 2 Bed  69037598918
# 102040                     Room in Queens, NY, near LGA.  56457739998
#
#        host_identity_verified  host name neighbourhood group  \
# 0                 UNCONFIRMED   Madaline            Brooklyn
# ...

# %%
data.reset_index(inplace = True) #because in above original data index has been jumped from 5 to 7 while cleaning.

# %%
type(data['instant_bookable'][50])   #check the updated column datatype
# Out:
# numpy.int64

# %% [markdown]
# ##### Recheckig few more columns if needs any update

# %%
type(data['price'][15])  #price column has str datatype and a '$' sign.
# Out:
# str

# %%
data['price'].str.replace("$", "")
# Out:
# 0          966
# 1          142
# 2          204
# 3          577
# 4        1,060
#           ...
# 99337      822
# 99338      455
# 99339    1,078
# 99340      103
# 99341      982
# Name: price, Length: 99342, dtype: object

# %%
data['price'] = data['price'].str.replace("$", "")

# %%
data['price'].str.replace(",", "")
# Out:
# 0         966
# 1         142
# 2         204
# 3         577
# 4        1060
#          ...
# 99337     822
# 99338     455
# 99339    1078
# 99340     103
# 99341     982
# Name: price, Length: 99342, dtype: object

# %%
data['price'] = data['price'].str.replace(",", "")

# %%
data['price'][15] #there is white space in the int
# Out:
# '1020 '

# %%
data['price'] = data['price'].str.replace(" ", "")

# %%
data['price'][15]
# Out:
# '1020'

# %%
type(data['price'][15]) #dataype needs to modify
# Out:
# str

# %%
data['price'] = data['price'].astype(int)

# %%
type(data['price'][15])
# Out:
# numpy.int64

# %%
data
# Out:
#                                                    Name      host id  \
# 0                    Clean & quiet apt home by the park  80014485718
# 1                                 Skylit Midtown Castle  52335172823
# 2      Entire Apt: Spacious Studio/Loft by central park  92037596077
# 3             Large Cozy 1 BR Apartment In Midtown East  45498551794
# 4                                       BlissArtsSpace!  90821839709
# ...                                                 ...          ...
# 99337            Cozy room in a 2B with backyard access   5155155913
# 99338                      An East Williamsburg Delight  71564706996
# 99339                      Cozy bedroom in williamsburg  83101851929
# 99340                            Spacious Room w/ 2 Bed  69037598918
# 99341                     Room in Queens, NY, near LGA.  56457739998
#
#       host_identity_verified  host name neighbourhood group  \
# 0                UNCONFIRMED   Madaline            Brooklyn
# ...

# %%
data.to_csv("Cleaned_data_airbnb.csv")

# %%
pd.read_csv("Cleaned_data_airbnb.csv")
# Out:
#        Unnamed: 0                                              Name  \
# 0               0                Clean & quiet apt home by the park
# 1               1                             Skylit Midtown Castle
# 2               2  Entire Apt: Spacious Studio/Loft by central park
# 3               3         Large Cozy 1 BR Apartment In Midtown East
# 4               4                                   BlissArtsSpace!
# ...           ...                                               ...
# 99337       99337            Cozy room in a 2B with backyard access
# 99338       99338                      An East Williamsburg Delight
# 99339       99339                      Cozy bedroom in williamsburg
# 99340       99340                            Spacious Room w/ 2 Bed
# 99341       99341                     Room in Queens, NY, near LGA.
#
#            host id host_identity_verified  host name neighbourhood group  \
# 0      80014485718            UNCONFIRMED   Madaline            Brooklyn
# ...

# %%
data.to_excel("Excel_cleaned_data_airbnb.xlsx")

# %%
pd.read_excel("Excel_cleaned_data_airbnb.xlsx")
# Out:
#        Unnamed: 0                                              Name  \
# 0               0                Clean & quiet apt home by the park
# 1               1                             Skylit Midtown Castle
# 2               2  Entire Apt: Spacious Studio/Loft by central park
# 3               3         Large Cozy 1 BR Apartment In Midtown East
# 4               4                                   BlissArtsSpace!
# ...           ...                                               ...
# 99337       99337            Cozy room in a 2B with backyard access
# 99338       99338                      An East Williamsburg Delight
# 99339       99339                      Cozy bedroom in williamsburg
# 99340       99340                            Spacious Room w/ 2 Bed
# 99341       99341                     Room in Queens, NY, near LGA.
#
#            host id host_identity_verified  host name neighbourhood group  \
# 0      80014485718            UNCONFIRMED   Madaline            Brooklyn
# ...
